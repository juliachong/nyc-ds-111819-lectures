# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user')
# Out:
#     user_id|age|gender|occupation|zip_code
# 0                  1|24|M|technician|85711
# 1                       2|53|F|other|94043
# 2                      3|23|M|writer|32067
# 3                  4|24|M|technician|43537
# 4                       5|33|F|other|15213
# ..                                     ...
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841
#
# [943 rows x 1 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
#users.groupby('occupation')['age'].mean()
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
import numpy as np
# create a new column of 'female' based on the colum of gender
users['male'] = np.where(users['gender']=='M', 1, 0)
#looks at the dataframe again and you can see all women are coded as 1 and men as 0
male = users.groupby('occupation')['male'].mean()

male.sort_values(ascending=False)
# now we can take the mean of the 'female' column 
# to see what percentage of the data is women.
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: male, dtype: float64

# %%
users[users['gender']=='M'][['age', 'occupation']].groupby('occupation').count()/users[['age', 'occupation']].groupby('occupation').mean()
# Out:
#                     age
# occupation
# administrator  1.109768
# artist         0.477816
# doctor         0.160656
# educator       1.642446
# engineer       1.786300
# entertainment  0.547529
# executive      0.748991
# healthcare     0.120301
# homemaker      0.030702
# lawyer         0.272109
# librarian      0.550000
# marketing      0.425358
# none           0.188285
# other          1.998621
# programmer     1.811528
# retired        0.206116
# salesman       0.252336
# scientist      0.787659
# student        6.158965
# technician     0.784358
# writer         0.716034

# %%
users[['occupation', 'female']].groupby('')

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation')['age'].aggregate([min,max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
#users.groupby('occupation')['gender'].describe()
import numpy as np
# create a new column of 'female' based on the column of gender
users['female'] = np.where(users['gender']=='F', 1, 0)
#looks at the dataframe again and you can see all women are coded as 1 and men as 0

users.groupby('occupation')['female'].mean()

# now we can take the mean of the 'female' column 
# to see what percentage of the data is women.
# Out:
# occupation
# administrator    0.455696
# artist           0.464286
# doctor           0.000000
# educator         0.273684
# engineer         0.029851
# entertainment    0.111111
# executive        0.093750
# healthcare       0.687500
# homemaker        0.857143
# lawyer           0.166667
# librarian        0.568627
# marketing        0.384615
# none             0.444444
# other            0.342857
# programmer       0.090909
# retired          0.071429
# salesman         0.250000
# scientist        0.096774
# student          0.306122
# technician       0.037037
# writer           0.422222
# Name: female, dtype: float64
